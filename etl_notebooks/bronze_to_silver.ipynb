# %% [markdown]
# # Data Reading

# %%
from pyspark.sql import SparkSession
from delta import configure_spark_with_delta_pip

builder = (
    SparkSession.builder
        .appName("Silver")
        .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
        .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
)

spark = configure_spark_with_delta_pip(builder).getOrCreate()

# %%
#importing modules
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
#Reading trip type CSV data

df_trip_type = spark.read\
                        .format("delta")\
                        .load(r"C:\Users\gauth\Desktop\Extended Meddalion Architecture\storage_bronze\trip_type")

# %%
df_trip_type.show()
# Out:
# +---------+-----------+
# |trip_type|description|
# +---------+-----------+
# |        1|Street-hail|
# |        2|   Dispatch|
# +---------+-----------+

# %%
#reading trip zone CSV data

df_trip_zone = spark.read\
                        .format("delta")\
                        .load(r"C:\Users\gauth\Desktop\Extended Meddalion Architecture\storage_bronze\trip_zone")

# %%
df_trip_zone.show(truncate=False)
# Out:
# +----------+-------------+-----------------------+------------+
# |LocationID|Borough      |Zone                   |service_zone|
# +----------+-------------+-----------------------+------------+
# |1         |EWR          |Newark Airport         |EWR         |
# |2         |Queens       |Jamaica Bay            |Boro Zone   |
# |3         |Bronx        |Allerton/Pelham Gardens|Boro Zone   |
# |4         |Manhattan    |Alphabet City          |Yellow Zone |
# |5         |Staten Island|Arden Heights          |Boro Zone   |
# |6         |Staten Island|Arrochar/Fort Wadsworth|Boro Zone   |
# |7         |Queens       |Astoria                |Boro Zone   |
# |8         |Queens       |Astoria Park           |Boro Zone   |
# |9         |Queens       |Auburndale             |Boro Zone   |
# |10        |Queens       |Baisley Park           |Boro Zone   |
# |11        |Brooklyn     |Bath Beach             |Boro Zone   |
# |12        |Manhattan    |Battery Park           |Yellow Zone |
# |13        |Manhattan    |Battery Park City      |Yellow Zone |
# |14        |Brooklyn     |Bay Ridge              |Boro Zone   |
# |15        |Queens       |Bay Terrace/Fort Totten|Boro Zone   |
# |16        |Queens       |Bayside                |Boro Zone   |
# |17        |Brooklyn     |Bedford                |Boro Zone   |
# |18        |Bronx        |Bedford Park           |Boro Zone   |
# |19        |Queens       |Bellerose              |Boro Zone   |
# |20        |Bronx        |Belmont                |Boro Zone   |
# +----------+-------------+-----------------------+------------+
# only showing top 20 rows

# %%
df_trip_data = spark.read\
                        .format("delta") \
                        .load(r"C:\Users\gauth\Desktop\Extended Meddalion Architecture\storage_bronze\trip_data")

# %%
df_trip_data.show()
# Out:
# +--------+--------------------+---------------------+------------------+----------+------------+------------+---------------+-------------+-----------+-----+-------+----------+------------+---------+---------------------+------------+------------+---------+--------------------+------------------+
# |VendorID|lpep_pickup_datetime|lpep_dropoff_datetime|store_and_fwd_flag|RatecodeID|PULocationID|DOLocationID|passenger_count|trip_distance|fare_amount|extra|mta_tax|tip_amount|tolls_amount|ehail_fee|improvement_surcharge|total_amount|payment_type|trip_type|congestion_surcharge|cbd_congestion_fee|
# +--------+--------------------+---------------------+------------------+----------+------------+------------+---------------+-------------+-----------+-----+-------+----------+------------+---------+---------------------+------------+------------+---------+--------------------+------------------+
# |       2| 2025-03-01 00:07:34|  2025-03-01 00:24:52|                 N|         1|          75|         239|              1|          2.2|       18.4|  1.0|    0.5|      5.91|         0.0|     NULL|                  1.0|       29.56|           1|        1|                2.75|               0.0|
# |       2| 2025-03-01 00:01:24|  2025-03-01 00:10:03|                 N|         1|          41|          42|              1|         1.06|        8.6|  1.0|    0.5|      3.33|         0.0|     NULL|                  1.0|       14.43|           1|        1|                 0.0|               0.0|
# |       2| 2025-03-01 00:45:03|  2025-03-01 01:05:38|                 N|         1|         265|          56|              1|        18.91|       69.5|  1.0|    0.5|       0.0|         0.0|     NULL|                  1.0|        72.0|           2|        1|                 0.0|               0.0|
# |       2| 2025-03-01 00

# +--------+--------------------+---------------------+------------------+----------+------------+------------+---------------+-------------+-----------+-----+-------+----------+------------+---------+---------------------+------------+------------+---------+--------------------+------------------+
# only showing top 20 rows

# %% [markdown]
# # Data Transformations

# %% [markdown]
# ### Trip Type

# %%
# description column is renamed to trip_description

df_trip_type = df_trip_type.withColumnRenamed("description","trip_description")

# %%
df_trip_type.show()
# Out:
# +---------+----------------+
# |trip_type|trip_description|
# +---------+----------------+
# |        1|     Street-hail|
# |        2|        Dispatch|
# +---------+----------------+

# %%
# writing trip type data to silver layer

df_trip_type.write.format("delta")\
                    .mode("overwrite")\
                    .option("path",r"C:\Users\gauth\Desktop\Extended Meddalion Architecture\storage_silver\trip_type")\
                    .save()

# %% [markdown]
# ### Trip Zone

# %%
df_trip_zone.show()
# Out:
# +----------+-------------+--------------------+------------+
# |LocationID|      Borough|                Zone|service_zone|
# +----------+-------------+--------------------+------------+
# |         1|          EWR|      Newark Airport|         EWR|
# |         2|       Queens|         Jamaica Bay|   Boro Zone|
# |         3|        Bronx|Allerton/Pelham G...|   Boro Zone|
# |         4|    Manhattan|       Alphabet City| Yellow Zone|
# |         5|Staten Island|       Arden Heights|   Boro Zone|
# |         6|Staten Island|Arrochar/Fort Wad...|   Boro Zone|
# |         7|       Queens|             Astoria|   Boro Zone|
# |         8|       Queens|        Astoria Park|   Boro Zone|
# |         9|       Queens|          Auburndale|   Boro Zone|
# |        10|       Queens|        Baisley Park|   Boro Zone|
# |        11|     Brooklyn|          Bath Beach|   Boro Zone|
# |        12|    Manhattan|        Battery Park| Yellow Zone|
# |        13|    Manhattan|   Battery Park City| Yellow Zone|
# |        14|     Brooklyn|           Bay Ridge|   Boro Zone|
# |        15|       Queens|Bay Terrace/Fort ...|   Boro Zone|
# |        16|       Queens|             Bayside|   Boro Zone|
# |        17|     Brooklyn|             Bedford|   Boro Zone|
# |        18|        Bronx|        Bedford Park|   Boro Zone|
# |        19|       Queens|           Bellerose|   Boro Zone|
# |        20|        Bronx|             Belmont|   Boro Zone|
# +----------+-------------+--------------------+------------+
# only showing top 20 rows

# %%
''' 
There are two zones in the zone column in some of the records, 
so we are splitting the zone column into two columns. 
Records which have only one zone will have `null` in the second column.
'''
df_trip_zone = df_trip_zone \
    .withColumn("zone1", expr("get(split(Zone, '/'), 0)")) \
    .withColumn("zone2", expr("get(split(Zone, '/'), 1)"))

# %%
df_trip_zone = df_trip_zone.drop("Zone")

# %%
df_trip_zone.show()
# Out:
# +----------+-------------+------------+-----------------+--------------+
# |LocationID|      Borough|service_zone|            zone1|         zone2|
# +----------+-------------+------------+-----------------+--------------+
# |         1|          EWR|         EWR|   Newark Airport|          NULL|
# |         2|       Queens|   Boro Zone|      Jamaica Bay|          NULL|
# |         3|        Bronx|   Boro Zone|         Allerton|Pelham Gardens|
# |         4|    Manhattan| Yellow Zone|    Alphabet City|          NULL|
# |         5|Staten Island|   Boro Zone|    Arden Heights|          NULL|
# |         6|Staten Island|   Boro Zone|         Arrochar|Fort Wadsworth|
# |         7|       Queens|   Boro Zone|          Astoria|          NULL|
# |         8|       Queens|   Boro Zone|     Astoria Park|          NULL|
# |         9|       Queens|   Boro Zone|       Auburndale|          NULL|
# |        10|       Queens|   Boro Zone|     Baisley Park|          NULL|
# |        11|     Brooklyn|   Boro Zone|       Bath Beach|          NULL|
# |        12|    Manhattan| Yellow Zone|     Battery Park|          NULL|
# |        13|    Manhattan| Yellow Zone|Battery Park City|          NULL|
# |        14|     Brooklyn|   Boro Zone|        Bay Ridge|          NULL|
# |        15|       Queens|   Boro Zone|      Bay Terrace|   Fort Totten|
# |        16|       Queens|   Boro Zone|          Bayside|          NULL|
# |        17|     Brooklyn|   Boro Zone|          Bedford|          NULL|
# |        18|        Bronx|   Boro Zone|     Bedford Park|          NULL|
# |        19|       Queens|   Boro Zone|        Bellerose|          NULL|
# |        20|        Bronx|   Boro Zone|          Belmont|          NULL|
# +----------+-------------+------------+-----------------+--------------+
# only showing top 20 rows

# %%
# write trip zone data to silver layer
df_trip_zone.write.format("delta")\
                    .mode("overwrite")\
                    .option("path",r"C:\Users\gauth\Desktop\Extended Meddalion Architecture\storage_silver\trip_zone")\
                    .save()

# %% [markdown]
# ### Trip Data

# %%
df_trip_data.count()
# Out:
# 543139

# %%
df_trip_data.summary().show()
# Out:
# +-------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-------------------+------------------+------------------+---------+---------------------+------------------+-------------------+-------------------+--------------------+-------------------+
# |summary|          VendorID|store_and_fwd_flag|        RatecodeID|      PULocationID|      DOLocationID|   passenger_count|     trip_distance|       fare_amount|             extra|            mta_tax|        tip_amount|      tolls_amount|ehail_fee|improvement_surcharge|      total_amount|       payment_type|          trip_type|congestion_surcharge| cbd_congestion_fee|
# +-------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-------------------+------------------+------------------+---------+---------------------+------------------+-------------------+-------------------+--------------------+-------------------+
# |  count|            543139|            499102|            499102|            543139|            543139|            499102|            543139|            543139|            543139|             543139|            543139|            543139|        0|               543139|            543139|             499102|             499056|              499102|             539315|
# |   mean| 2.059874175855536|              NULL|1.3052201754350814| 96.80247229530562|142.90042143907914|1.2912470797552404|18.430377398787424|18.177960577311538|0.8867670154417193| 0.5758162275218682| 2.669662406860957|0.2655851264593441|     NULL|    0.958727139829889|25.229211601449837| 1.2605980340691882| 1.0554186303741464|  0.8751918445528168|0.07026830331068114|
# | stddev|0.8913573653221256|              NULL|  2.66336217368884|56.420476768705505| 77.24264602846667|0.9393604396893387|1137.1650293145576|17.730758751480415|1.3851288264150896|0.35147904234433613|3.6487443090097735|1.4401422405091653|     NULL|  0.19108424569205756|19.992737330141697|0.46996782572966167|0.22879578377815374|   1.281181655930487|0.21861106874862732|
# |    min|                 1|                 N|                 1|                 1|                 1|                 0|               0.0|            -470.6|              -6.0|               -0.5|            -100.0|             -6.94|     NULL|                 -1.0|            -473.1|                  1|                  1|               -2.75|              -0.75|
# |    25%|                 2|              NULL|                 1|                74|                74|                 1|              1.21|               9.3|               0.0|                0.5|               0.0|               0.0|     NULL|                  1.0|             14.64|                  1|                  1|                 0.0|                0.0|
# |    50%|                 2|              NULL|                 1|                75|               140|                 1|              1.98|             13.58|               0.0|                0.5|              2.08|               0.0|     NULL|                  1.0|             20.02|                  1|                  1|                 0.0|                0.0|
# |    75%|                 2|              NULL|                 1|                97|               230|                 1|              3.51|              20.5|               1.0|                0.5|              3.92|               0.0|     NULL|                  1.0|             29.25|                  1|                  1|                2.75|                0.0|
# |    max|                 6|                 Y|                99|               265|               265|                 9|         256323.18|            1086.6|              12.5|               61.5|             350.0|             108.0|     NULL|                  1.0|           1095.54|                  5|                  2|                2.75|               0.75|
# +-------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-------------------+------------------+------------------+---------+---------------------+------------------+-------------------+-------------------+--------------------+-------------------+

# %%
df_trip_data.select([
    approx_count_distinct(c).alias(c)
    for c in df_trip_data.columns
]).show()
# Out:
# +--------+----------+---------+------------+------------+-------------+-----------+------------+
# |VendorID|trip_month|trip_year|PULocationID|DOLocationID|trip_distance|fare_amount|total_amount|
# +--------+----------+---------+------------+------------+-------------+-----------+------------+
# |       3|        12|        2|         255|         262|         3333|       5706|        9730|
# +--------+----------+---------+------------+------------+-------------+-----------+------------+

# %%
# convert timestamp to date, moth and year, and add them as columns
df_trip_data = df_trip_data.withColumn('trip_date',to_date('lpep_pickup_datetime'))\
                           .withColumn('trip_year',year('trip_date'))\
                           .withColumn('trip_month',month('trip_date'))
df_trip_data.show()
# Out:
# +--------+--------------------+---------------------+------------------+----------+------------+------------+---------------+-------------+-----------+-----+-------+----------+------------+---------+---------------------+------------+------------+---------+--------------------+------------------+----------+---------+----------+
# |VendorID|lpep_pickup_datetime|lpep_dropoff_datetime|store_and_fwd_flag|RatecodeID|PULocationID|DOLocationID|passenger_count|trip_distance|fare_amount|extra|mta_tax|tip_amount|tolls_amount|ehail_fee|improvement_surcharge|total_amount|payment_type|trip_type|congestion_surcharge|cbd_congestion_fee| trip_date|trip_year|trip_month|
# +--------+--------------------+---------------------+------------------+----------+------------+------------+---------------+-------------+-----------+-----+-------+----------+------------+---------+---------------------+------------+------------+---------+--------------------+------------------+----------+---------+----------+
# |       2| 2025-05-01 00:17:04|  2025-05-01 00:56:06|                 N|         1|          25|         216|              1|         9.34|       44.3|  1.0|    0.5|       0.0|         0.0|     NULL|                  1.0|        46.8|           1|        1|                 0.0|               0.0|2025-05-01|     2025|         5|
# |       2| 2025-05-01 00:56:16|  2025-05-01 01:10:26|                 N|         1|         160|         129|              1|         2.95|       16.3|  1.0|    0.5|       0.0|         0.0|     NULL|                  1.0|        18.8|           2|        1|                 0.0|               0.0|2025-05-01|     2025|         5|
# |       1| 2025-05-01 00:24:49|  2025-05-01 00:42:29|                 N|         1|         260|         179|              1|          3.0|       18.4|  1.0|    1.5|       0.0|         0.0|     NULL|                  1.0|        20.9|           2|        1|                 0.0|               0.0|2025-05-01|     2025|         5|
# |       2| 2025-05-01 00:27:11|  2025-05-01 00:33:21|                 N|         1|         130|         216|              1|         1.61|        9.3|  1.0|    0.5|       0.0|         0.0|     NULL|                  1.0|        11.8|           2|        1|                 0.0|               0.0|2025-05-01|     2025|         5|
# |       2| 2025-05-01 00:32:59|  2025-05-01 00:41:34|                 N|         1|         244|         151|              2|         3.44|       15.6|  1.0|    0.5|      4.52|         0.0|     NULL|                  1.0|       22.62|           1|        1|                 0.0|               0.0|2025-05-01|     2025|         5|
# |       2| 2025-04-30 23:58:57|  2025-05-01 00:02:31|                 N|         1|          42|          41|              1|         0.66|        6.5|  1.0|    0.5|       2.0|         0.0|     NULL|                  1.0|        11.0|           1|        1|                 0.0|               0.0|2025-04-30|     2025|         4|
# |       2| 2025-05-01 00:38:03|  2025-05-01 00:43:28|                 N|         1|         240|         265|              1|         1.63|        9.3|  1.0|    0.5|       0.0|         0.0|     NULL|                  1.0|        11.8|           1|        1|                 0.0|               0.0|2025-05-01|     2025|         5|
# |       2| 2025-05-01 00:13:48|  2025-05-01 00:26:19|                 N|         1|         129|          70|              1|         2.15|       13.5|  1.0|    0.5|       0.0|         0.0|     NULL|                  1.0|        16.0|           2|        1|                 0.0|               0.0|2025-05-01|     2025|         5|
# |       2| 2025-05-01 00:08:00|  2025-05-01 00:22:00|                 N|         1|         244|          42|              1|         2.87|       15.6|  1.0|    0.5|       0.0|         0.0|     NULL|                  1.0|        18.1|           2|        1|                 0.0|               0.0|2025-05-01|     2025|         5|
# |       2| 2025-05-01 00:48:03|  2025-05-01 00:57:01|                 N|         1|          75|         262|              1|         1.52|       10.7|  1.0|    0.5|      2.39|         0.0|     NULL|                  1.0|       18.34|           1|        1|                2.75|               0.0|2025-05-01|     2025|         5|
# |       2| 2025-05-01 00:22:47|  2025-05-01 00:23:46|                 N|         5|          82|         264|              1|         0.08|        9.0|  0.0|    0.0|       0.0|         0.0|     NULL|                  1.0|        10.0|           2|        2|                 0.0|               0.0|2025-05-01|     2025|         5|
# |       2| 2025-05-01 00:25:41|  2025-05-01 00:25:47|                 N|         5|          82|          82|              1|          0.0|        9.0|  0.0|    0.0|       0.0|         0.0|     NULL|                  1.0|        10.0|           1|        2|                 0.0|               0.0|2025-05-01|     2025|         5|
# |       2| 2025-04-30 23:53:09|  2025-05-01 00:05:16|                 N|         1|         130|         218|              1|         2.66|       14.9|  1.0|    0.5|       1.0|         0.0|     NULL|                  1.0|        18.4|           1|        1|                 0.0|               0.0|2025-04-30|     2025|         4|
# |       2| 2025-05-01 00:07:18|  2025-05-01 00:14:26|                 N|         1|         146|         179|              1|         1.47|       10.0|  1.0|    0.5|      3.12|         0.0|     NULL|                  1.0|       15.62|           1|        1|                 0.0|               0.0|2025-05-01|     2025|         5|
# |       2| 2025-05-01 00:37:32|  2025-05-01 00:48:16|                 N|         1|          74|         166|              1|         1.44|       12.1|  1.0|    0.5|      2.92|         0.0|     NULL|                  1.0|       17.52|           1|        1|                 0.0|               0.0|2025-05-01|     2025|         5|
# |       2| 2025-05-01 00:11:28|  2025-05-01 00:18:58|                 N|         1|          95|         196|              1|         1.54|        9.3|  1.0|    0.5|       0.0|         0.0|     NULL|                  1.0|        11.8|           2|        1|                 0.0|               0.0|2025-05-01|     2025|         5|
# |       2| 2025-05-01 00:12:34|  2025-05-01 00:40:35|                 N|         1|          66|          48|              5|         5.29|       27.5|  1.0|    0.5|      5.08|         0.0|     NULL|                  1.0|       38.58|           1|        1|                2.75|              0.75|2025-05-01|     2025|         5|
# |       2| 2025-05-01 00:36:23|  2025-05-01 00:46:45|                 N|         1|          74|         238|              1|         2.63|       14.2|  1.0|    0.5|      4.18|         0.0|     NULL|                  1.0|       20.88|           1|        1|                 0.0|               0.0|2025-05-01|     2025|         5|
# |       2| 2025-05-01 00:57:24|  2025-05-01 01:03:42|                 N|         1|         166|         152|              1|          1.4|        9.3|  1.0|    0.5|      2.36|         0.0|     NULL|                  1.0|       14.16|           1|        1|                 0.0|               0.0|2025-05-01|     2025|         5|
# |       2| 2025-05-01 00:36:23|  2025-05-01 00:39:57|                 N|         1|         129|         129|              1|         0.56|        5.8|  1.0|    0.5|       5.0|         0.0|     NULL|                  1.0|        13.3|           1|        1|                 0.0|               0.0|2025-05-01|     2025|         5|
# +--------+--------------------+---------------------+------------------+----------+------------+------------+---------------+-------------+-----------+-----+-------+----------+------------+---------+---------------------+------------+------------+---------+--------------------+------------------+----------+---------+----------+
# only showing top 20 rows

# %%
df_trip_data = df_trip_data.select('VendorID','trip_month','trip_year','PULocationID','DOLocationID','trip_distance','fare_amount','total_amount')
df_trip_data.show()
# Out:
# +--------+----------+---------+------------+------------+-------------+-----------+------------+
# |VendorID|trip_month|trip_year|PULocationID|DOLocationID|trip_distance|fare_amount|total_amount|
# +--------+----------+---------+------------+------------+-------------+-----------+------------+
# |       2|         5|     2025|          25|         216|         9.34|       44.3|        46.8|
# |       2|         5|     2025|         160|         129|         2.95|       16.3|        18.8|
# |       1|         5|     2025|         260|         179|          3.0|       18.4|        20.9|
# |       2|         5|     2025|         130|         216|         1.61|        9.3|        11.8|
# |       2|         5|     2025|         244|         151|         3.44|       15.6|       22.62|
# |       2|         4|     2025|          42|          41|         0.66|        6.5|        11.0|
# |       2|         5|     2025|         240|         265|         1.63|        9.3|        11.8|
# |       2|         5|     2025|         129|          70|         2.15|       13.5|        16.0|
# |       2|         5|     2025|         244|          42|         2.87|       15.6|        18.1|
# |       2|         5|     2025|          75|         262|         1.52|       10.7|       18.34|
# |       2|         5|     2025|          82|         264|         0.08|        9.0|        10.0|
# |       2|         5|     2025|          82|          82|          0.0|        9.0|        10.0|
# |       2|         4|     2025|         130|         218|         2.66|       14.9|        18.4|
# |       2|         5|     2025|         146|         179|         1.47|       10.0|       15.62|
# |       2|         5|     2025|          74|         166|         1.44|       12.1|       17.52|
# |       2|         5|     2025|          95|         196|         1.54|        9.3|        11.8|
# |       2|         5|     2025|          66|          48|         5.29|       27.5|       38.58|
# |       2|         5|     2025|          74|         238|         2.63|       14.2|       20.88|
# |       2|         5|     2025|         166|         152|          1.4|        9.3|       14.16|
# |       2|         5|     2025|         129|         129|         0.56|        5.8|        13.3|
# +--------+----------+---------+------------+------------+-------------+-----------+------------+
# only showing top 20 rows

# %%
# filter out illogical negative values 
df_trip_data = df_trip_data \
                .filter(col("fare_amount") > lit(0)) \
                .filter(col("total_amount") > lit(0)) \
                .filter(col("trip_distance") > lit(0)) \
                .filter

# %%
df_trip_data.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>VendorID</th><th>trip_date</th><th>PULocationID</th><th>DOLocationID</th><th>trip_distance</th><th>fare_amount</th><th>total_amount</th></tr></thead><tbody><tr><td>2</td><td>2023-03-01</td><td>82</td><td>196</td><td>2.36</td><td>13.5</td><td>16.0</td></tr><tr><td>2</td><td>2023-03-01</td><td>7</td><td>7</td><td>0.78</td><td>6.5</td><td>9.0</td></tr><tr><td>2</td><td>2023-02-28</td><td>166</td><td>74</td><td>1.66</td><td>11.4</td><td>16.68</td></tr><tr><td>2</td><td>2023-03-01</td><td>236</td><td>229</td><td>3.14</td><td>15.6</td><td>25.02</td></tr><tr><td>2</td><td>2023-03-01</td><td>75</td><td>235</td><td>5.69</td><td>23.3</td><td>29.8</td></tr><tr><td>2</td><td>2023-03-01</td><td>260</td><td>160</td><td>2.92</td><td>17.7</td><td>24.24</td></tr><tr><td>2</td><td>2023-03-01</td><td>244</td><td>41</td><td>3.34</td><td>16.3</td><td>24.44</td></tr><tr><td>2</td><td>2023-03-01</td><td>83</td><td>7</td><td>1.75</td><td>10.7</td><td>15.84</td></tr><tr><td>2</td><td>2023-03-01</td><td>223</td><td>223</td><td>0.74</td><td>5.1</td><td>9.12</td></tr><tr><td>2</td><td>2023-03-01</td><td>260</td><td>260</td><td>0.63</td><td>6.5</td><td>10.8</td></tr><tr><td>2</td><td>2023-03-01</td><td>82</td><td>193</td><td>2.94</td><td>19.8</td><td>22.3</td></tr><tr><td>2</td><td>2023-03-01</td><td>146</td><td>145</td><td>0.36</td><td>5.8</td><td>8.3</td></tr><tr><td>2</td><td>2023-03-01</td><td>130</td><td>191</td><td>3.59</td><td>19.1</td><td>25.92</td></tr><tr><td>2</td><td>2023-03-01</td><td>95</td><td>134</td><td>2.0</td